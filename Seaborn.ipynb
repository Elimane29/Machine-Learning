# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
# !pip install openpyxl

# %%
#data = pd.read_csv(r'C:\Users\LENOVO T480\Downloads\diamonds.csv')

data= pd.read_csv(r'C:\Users\LENOVO T480\Documents\diamonds.csv')

# %%
data.head()
# Out:
#    Unnamed: 0  carat      cut color clarity  depth  table  price     x     y  \
# 0           1   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98
# 1           2   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84
# 2           3   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07
# 3           4   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23
# 4           5   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35
#
#       z
# 0  2.43
# 1  2.31
# 2  2.31
# 3  2.63
# 4  2.75

# %%
X= data['cut'] == 'Ideal'
print(X)
# Out:
# 0         True
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 53935     True
# 53936    False
# 53937    False
# 53938    False
# 53939     True
# Name: cut, Length: 53940, dtype: bool

# %%
data.describe()
# Out:
#          Unnamed: 0         carat         depth         table         price  \
# count  53940.000000  53940.000000  53940.000000  53940.000000  53940.000000
# mean   26970.500000      0.797940     61.749405     57.457184   3932.799722
# std    15571.281097      0.474011      1.432621      2.234491   3989.439738
# min        1.000000      0.200000     43.000000     43.000000    326.000000
# 25%    13485.750000      0.400000     61.000000     56.000000    950.000000
# 50%    26970.500000      0.700000     61.800000     57.000000   2401.000000
# 75%    40455.250000      1.040000     62.500000     59.000000   5324.250000
# max    53940.000000      5.010000     79.000000     95.000000  18823.000000
#
#                   x             y             z
# count  53940.000000  53940.000000  53940.000000
# mean       5.731157      5.734526      3.538734
# std        1.121761      1.142135      0.705699
# min        0.000000      0.000000      0.000000
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  53940 non-null  int64
#  1   carat       53940 non-null  float64
#  2   cut         53940 non-null  object
#  3   color       53940 non-null  object
#  4   clarity     53940 non-null  object
#  5   depth       53940 non-null  float64
#  6   table       53940 non-null  float64
#  7   price       53940 non-null  int64
#  8   x           53940 non-null  float64
#  9   y           53940 non-null  float64
#  10  z           53940 non-null  float64
# dtypes: float64(6), int64(2), object(3)
# memory usage: 4.5+ MB

# %%
data_quality = data[data['cut'] == 'Ideal'] #data[data['age']<18]
data_quality
# Out:
#        Unnamed: 0  carat    cut color clarity  depth  table  price     x  \
# 0               1   0.23  Ideal     E     SI2   61.5   55.0    326  3.95
# 11             12   0.23  Ideal     J     VS1   62.8   56.0    340  3.93
# 13             14   0.31  Ideal     J     SI2   62.2   54.0    344  4.35
# 16             17   0.30  Ideal     I     SI2   62.0   54.0    348  4.31
# 39             40   0.33  Ideal     I     SI2   61.8   55.0    403  4.49
# ...           ...    ...    ...   ...     ...    ...    ...    ...   ...
# 53925       53926   0.79  Ideal     I     SI1   61.6   56.0   2756  5.95
# 53926       53927   0.71  Ideal     E     SI1   61.9   56.0   2756  5.71
# 53929       53930   0.71  Ideal     G     VS1   61.4   56.0   2756  5.76
# 53935       53936   0.72  Ideal     D     SI1   60.8   57.0   2757  5.75
# 53939       53940   0.75  Ideal     D     SI2   62.2   55.0   2757  5.83
#
#           y     z
# 0      3.98  2.43
# 11     3.90  2.46
# 13     4.37  2.71
# ...

# %%
X=data_quality[data_quality['price'] < 2500]
X
# Out:
#        Unnamed: 0  carat    cut color clarity  depth  table  price     x  \
# 0               1   0.23  Ideal     E     SI2   61.5   55.0    326  3.95
# 11             12   0.23  Ideal     J     VS1   62.8   56.0    340  3.93
# 13             14   0.31  Ideal     J     SI2   62.2   54.0    344  4.35
# 16             17   0.30  Ideal     I     SI2   62.0   54.0    348  4.31
# 39             40   0.33  Ideal     I     SI2   61.8   55.0    403  4.49
# ...           ...    ...    ...   ...     ...    ...    ...    ...   ...
# 53634       53635   0.30  Ideal     D     SI1   61.6   56.0    552  4.30
# 53635       53636   0.30  Ideal     I    VVS1   62.1   56.0    552  4.30
# 53636       53637   0.30  Ideal     D     SI1   61.6   57.0    552  4.28
# 53638       53639   0.30  Ideal     D     SI1   61.0   57.0    552  4.29
# 53639       53640   0.30  Ideal     D     SI1   61.0   56.0    552  4.35
#
#           y     z
# 0      3.98  2.43
# 11     3.90  2.46
# 13     4.37  2.71
# ...

# %%
X[X['price'] >= 1000] #data[data['age']<18]
# Out:
#        Unnamed: 0  carat    cut color clarity  depth  table  price     x  \
# 37783       37784   0.38  Ideal     E     VS1   61.6   56.0   1000  4.65
# 37786       37787   0.38  Ideal     E     VS1   61.9   56.0   1000  4.63
# 37788       37789   0.30  Ideal     D    VVS1   61.3   57.0   1000  4.29
# 37791       37792   0.30  Ideal     D    VVS1   61.1   57.0   1000  4.34
# 37792       37793   0.38  Ideal     E     VS1   62.1   56.0   1000  4.62
# ...           ...    ...    ...   ...     ...    ...    ...    ...   ...
# 52331       52332   0.78  Ideal     G     SI1   61.0   57.0   2496  5.94
# 52335       52336   0.74  Ideal     H     VS2   62.5   54.0   2497  5.76
# 52342       52343   0.72  Ideal     I     VS1   61.4   58.0   2498  5.73
# 52347       52348   0.55  Ideal     E    VVS2   61.4   56.0   2499  5.28
# 52348       52349   0.70  Ideal     H     SI1   61.8   53.0   2499  5.71
#
#           y     z
# 37783  4.67  2.87
# 37786  4.67  2.88
# 37788  4.32  2.64
# ...

# %%
sns.pairplot(data)

# %%
sns.pairplot(data, hue = 'color')
